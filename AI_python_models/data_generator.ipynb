# %%
import time
import joblib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import (
    ConfusionMatrixDisplay, 
    precision_recall_curve, 
    roc_curve, 
    auc
)
from traditional_split_data import data_split

from preprocess_data_legacy_pipeline import load_data, prepare_date_for_model, prepare_text_classic, prepare_context_generic, add_count_proportions, process_subject, remove_unused_columns
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Usuario\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Usuario\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Usuario\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
models = {
'XGBoost'   : joblib.load('xgboost_pipeline.joblib')
}

df = load_data('liar2_no_null_data.csv')
# Out:
# e:\Master\TFM\FakeNewsReactApp\.venv\lib\site-packages\xgboost\core.py:158: UserWarning: [21:29:25] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\data\../common/error_msg.h:80: If you are loading a serialized model (like pickle in Python, RDS in R) or
# configuration generated by an older version of XGBoost, please export the model by calling
# `Booster.save_model` from that version first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/stable/tutorials/saving_model.html
#
# for more details about differences between saving model and serializing.
#
#   warnings.warn(smsg, UserWarning)

# %%
from sklearn.model_selection import train_test_split

# train_test_split hace un muestreo estratificado
_, df_stratified = train_test_split(
    df,
    test_size=15,
    stratify=df['label'],
    random_state=200900
)

print(df_stratified)

df_stratified = df_stratified.drop(columns=['label'])

df_stratified.head(15)
# Out:
#           id  label                                          statement  \
# 20368   1786      4  The addition of a 1 percent sales tax would co...
# 8157   22312      0  The Michigan attorney general's race was "stol...
# 18997  10823      5  Sen. Sanders did vote five times against the B...
# 10984  15845      0  Right here (in West Virginia), they are buildi...
# 13676  18420      1  There's no court session between now and the e...
# 13196  19551      3  The proposal by President Joe Biden would put ...
# 10770  13846      2  In the Alabama Senate runoff, "the candidate I...
# 10741   3097      1  The government will "go out and buy my breast ...
# 14969  22059      2  Lee County, Florida, wasn't "even in the cone"...
# 17105   1057      3  Medicare has at least $80 billion worth of fra...
# 17596  17115      1  Says the United Nations plans to "implant ever...
# 21953  22925      1                    Israel is banning Christianity.
# 10366   8372      3  In 2002, "Iran was more or less an American ally.
# 18617   4004      5  The deficit was on track to top $1 trillion th...
# 6478   11998      4  Says middle-class New York State residents wil...
#
#                      date                                            subject  \
# 20368       June 18, 2010  economy;energy;infrastructure;transportation;u...
# 8157     November 9, 2022                     elections;facebook fact-checks
# 18997    October 13, 2015                                               guns
# 10984       March 5, 2019             immigration;housing;race and ethnicity
# 13676  September 20, 2020                                      supreme court
# 13196       April 4, 2021                                 corporations;taxes
# 10770  September 30, 2017                           polls and public opinion
# 10741   February 15, 2011                            health care;women;taxes
# 14969     October 2, 2022                                        environment
# 17105     August 24, 2009                               health care;medicare
# 17596   February 20, 2020      fake news;privacy issues;facebook fact-checks
# 21953      April 20, 2023               israel;religion;facebook fact-checks
# 10366    January 28, 2014                          foreign policy;punditfact
# 18617       July 25, 2011                             deficit;federal budget
# 6478        June 22, 2016                                              taxes
#
#                                   speaker  \
# 20368  hillsborough area regional transit
# 8157                      instagram posts
# 18997                     hillary clinton
# 10984                      facebook posts
# 13676                           joe biden
# 13196                           roy blunt
# 10770                        donald trump
# 10741                    michele bachmann
# 14969                        ron desantis
# 17105                          tom coburn
# 17596                            bloggers
# 21953                      facebook posts
# 10366                     andrea mitchell
# 18617                        barack obama
# 6478                         andrew cuomo
#
#                                      speaker_description  true_counts  \
# 20368  Hillsborough Area Rapid Transit, or HART, is t...            0
# 8157   Posters on Instagram, where people share photo...            3
# 18997  Hillary Clinton was the 2016 Democratic nomine...           72
# 10984  Posters on Facebook and other social media net...           24
# 13676  Joe Biden is the president of the United State...           25
# 13196  Roy Blunt is the junior U.S. senator from Miss...            5
# 10770  Donald Trump is the former president of the Un...           36
# 10741  Michele Bachmann, first elected to the U.S. Co...            5
# 14969  Ron DeSantis announced on May 24, 2023 that he...            2
# 17105  Tom Coburn is a former U.S. Senator from Oklah...            0
# 17596                       Blog posting on the Internet            8
# 21953  Posters on Facebook and other social media net...           24
# 10366  Andrea Mitchell is a journalist for NBC and MS...            0
# 18617  Barack Obama is the former president of the Un...          124
# 6478   Andrew Cuomo, a Democrat, was elected to his f...           15
#
#        mostly_true_counts  half_true_counts  mostly_false_counts  \
# 20368                   1                 0                    0
# 8157                    3                15                   51
# 18997                  76                70                   43
# 10984                  50               108                  245
# 13676                  64                65                   52
# 13196                   2                 4                    3
# 10770                  85               120                  194
# 10741                   4                 6                    8
# 14969                  10                 9                   13
# 17105                   2                 3                    2
# 17596                  18                24                   53
# 21953                  50               108                  245
# 10366                   2                 1                    0
# 18617                 165               163                   71
# 6478                    5                 8                    7
#
#        false_counts  pants_on_fire_counts  \
# 20368             0                     0
# 8157            405                   140
# 18997            31                     9
# 10984          1410                   570
# 13676            55                     7
# 13196             3                     1
# 10770           360                   179
# 10741            23                    16
# 14969            14                     2
# 17105             3                     0
# 17596           233                   396
# 21953          1410                   570
# 10366             1                     0
# 18617            71                     9
# 6478              3                     0
#
#                                                  context  \
# 20368                                         a brochure
# 8157                                   an Instagram post
# 18997                        the first Democratic debate
# 10984                              posts on the Internet
# 13676                                       Philadelphia
# 13196                       remarks on "Fox News Sunday"
# 10770                                            a tweet
# 10741          an interview on "The Laura Ingraham Show"
# 14969                              an interview with CNN
# 17105  Fox News Channel's On the Record With Greta Va...
# 17596                                            a story
# 21953                                   a Facebook video
# 10366   a broadcast of MSNBC's "Andrea Mitchell Reports"
# 18617                                a televised address
# 6478   a press conference and several other recent pu...
#
#                                            justification
# 20368  “The real number is probably somewhere in betw...
# 8157   The site showed Nessel with 2,320,440 votes, a...
# 18997  Clinton said, "Sen. Sanders did vote five time...
# 10984  The 2017 video said that in West Virginia, "th...
# 13676  Biden said, "There's no court session between ...
# 13196  Blunt said Biden’s proposal would put the U.S....
# 10770  Trump tweeted that in the recent Alabama Senat...
# 10741  It’s a catchy sound bite, but like a lot of so...
# 14969  Most of Lee County was not within Hurricane Ia...
# 17105  He added that Coburn "doesn't know any more th...
# 17596  Since then, biometric technology has been deve...
# 21953  Gafni said he does not intend to advance the l...
# 10366  Mitchell said that in 2002, Iran was almost an...
# 18617  "But even with all of this waste, the deficit ...
# 6478   Governor Andrew M. Cuomo claimed new tax rates...
#           id                                          statement  \
# 20368   1786  The addition of a 1 percent sales tax would co...
# 8157   22312  The Michigan attorney general's race was "stol...
# 18997  10823  Sen. Sanders did vote five times against the B...
# 10984  15845  Right here (in West Virginia), they are buildi...
# 13676  18420  There's no court session between now and the e...
# 13196  19551  The proposal by President Joe Biden would put ...
# 10770  13846  In the Alabama Senate runoff, "the candidate I...
# 10741   3097  The government will "go out and buy my breast ...
# 14969  22059  Lee County, Florida, wasn't "even in the cone"...
# 17105   1057  Medicare has at least $80 billion worth of fra...
# 17596  17115  Says the United Nations plans to "implant ever...
# 21953  22925                    Israel is banning Christianity.
# 10366   8372  In 2002, "Iran was more or less an American ally.
# 18617   4004  The deficit was on track to top $1 trillion th...
# 6478   11998  Says middle-class New York State residents wil...
#
#                      date                                            subject  \
# 20368       June 18, 2010  economy;energy;infrastructure;transportation;u...
# 8157     November 9, 2022                     elections;facebook fact-checks
# 18997    October 13, 2015                                               guns
# 10984       March 5, 2019             immigration;housing;race and ethnicity
# 13676  September 20, 2020                                      supreme court
# 13196       April 4, 2021                                 corporations;taxes
# 10770  September 30, 2017                           polls and public opinion
# 10741   February 15, 2011                            health care;women;taxes
# 14969     October 2, 2022                                        environment
# 17105     August 24, 2009                               health care;medicare
# 17596   February 20, 2020      fake news;privacy issues;facebook fact-checks
# 21953      April 20, 2023               israel;religion;facebook fact-checks
# 10366    January 28, 2014                          foreign policy;punditfact
# 18617       July 25, 2011                             deficit;federal budget
# 6478        June 22, 2016                                              taxes
#
#                                   speaker  \
# 20368  hillsborough area regional transit
# 8157                      instagram posts
# 18997                     hillary clinton
# 10984                      facebook posts
# 13676                           joe biden
# 13196                           roy blunt
# 10770                        donald trump
# 10741                    michele bachmann
# 14969                        ron desantis
# 17105                          tom coburn
# 17596                            bloggers
# 21953                      facebook posts
# 10366                     andrea mitchell
# 18617                        barack obama
# 6478                         andrew cuomo
#
#                                      speaker_description  true_counts  \
# 20368  Hillsborough Area Rapid Transit, or HART, is t...            0
# 8157   Posters on Instagram, where people share photo...            3
# 18997  Hillary Clinton was the 2016 Democratic nomine...           72
# 10984  Posters on Facebook and other social media net...           24
# 13676  Joe Biden is the president of the United State...           25
# 13196  Roy Blunt is the junior U.S. senator from Miss...            5
# 10770  Donald Trump is the former president of the Un...           36
# 10741  Michele Bachmann, first elected to the U.S. Co...            5
# 14969  Ron DeSantis announced on May 24, 2023 that he...            2
# 17105  Tom Coburn is a former U.S. Senator from Oklah...            0
# 17596                       Blog posting on the Internet            8
# 21953  Posters on Facebook and other social media net...           24
# 10366  Andrea Mitchell is a journalist for NBC and MS...            0
# 18617  Barack Obama is the former president of the Un...          124
# 6478   Andrew Cuomo, a Democrat, was elected to his f...           15
#
#        mostly_true_counts  half_true_counts  mostly_false_counts  \
# 20368                   1                 0                    0
# 8157                    3                15                   51
# 18997                  76                70                   43
# 10984                  50               108                  245
# 13676                  64                65                   52
# 13196                   2                 4                    3
# 10770                  85               120                  194
# 10741                   4                 6                    8
# 14969                  10                 9                   13
# 17105                   2                 3                    2
# 17596                  18                24                   53
# 21953                  50               108                  245
# 10366                   2                 1                    0
# 18617                 165               163                   71
# 6478                    5                 8                    7
#
#        false_counts  pants_on_fire_counts  \
# 20368             0                     0
# 8157            405                   140
# 18997            31                     9
# 10984          1410                   570
# 13676            55                     7
# 13196             3                     1
# 10770           360                   179
# 10741            23                    16
# 14969            14                     2
# 17105             3                     0
# 17596           233                   396
# 21953          1410                   570
# 10366             1                     0
# 18617            71                     9
# 6478              3                     0
#
#                                                  context  \
# 20368                                         a brochure
# 8157                                   an Instagram post
# 18997                        the first Democratic debate
# 10984                              posts on the Internet
# 13676                                       Philadelphia
# 13196                       remarks on "Fox News Sunday"
# 10770                                            a tweet
# 10741          an interview on "The Laura Ingraham Show"
# 14969                              an interview with CNN
# 17105  Fox News Channel's On the Record With Greta Va...
# 17596                                            a story
# 21953                                   a Facebook video
# 10366   a broadcast of MSNBC's "Andrea Mitchell Reports"
# 18617                                a televised address
# 6478   a press conference and several other recent pu...
#
#                                            justification
# 20368  “The real number is probably somewhere in betw...
# 8157   The site showed Nessel with 2,320,440 votes, a...
# 18997  Clinton said, "Sen. Sanders did vote five time...
# 10984  The 2017 video said that in West Virginia, "th...
# 13676  Biden said, "There's no court session between ...
# 13196  Blunt said Biden’s proposal would put the U.S....
# 10770  Trump tweeted that in the recent Alabama Senat...
# 10741  It’s a catchy sound bite, but like a lot of so...
# 14969  Most of Lee County was not within Hurricane Ia...
# 17105  He added that Coburn "doesn't know any more th...
# 17596  Since then, biometric technology has been deve...
# 21953  Gafni said he does not intend to advance the l...
# 10366  Mitchell said that in 2002, Iran was almost an...
# 18617  "But even with all of this waste, the deficit ...
# 6478   Governor Andrew M. Cuomo claimed new tax rates...

# %%
from dataclasses import dataclass
from datetime import datetime

@dataclass
class Noticia:
    title: str
    source: str
    date: datetime
    veracity: int
    image: str
    url: str
    explanation: str = ""

# %%
noticias = []


for _, data in df_stratified.iterrows():
    
    fecha = pd.to_datetime(data['date'], format='%B %d, %Y', errors='coerce').strftime('%Y-%m-%d')

    noticia = Noticia(
        title=data['statement'],
        source=data['context'].lower().capitalize(),
        date=fecha,
        veracity=0,
        image="",                 
        url="",                   
        explanation=""
    )
    noticias.append(noticia)

print(noticias)
# Out:
# [Noticia(title='The addition of a 1 percent sales tax would cost a typical household in Hillsborough County approximately $12 a month.', source='A brochure', date='2010-06-18', veracity=0, image='', url='', explanation=''), Noticia(title='The Michigan attorney general\'s race was "stolen in the middle of the night from Matt DePerno.', source='An instagram post', date='2022-11-09', veracity=0, image='', url='', explanation=''), Noticia(title='Sen. Sanders did vote five times against the Brady bill.', source='The first democratic debate', date='2015-10-13', veracity=0, image='', url='', explanation=''), Noticia(title='Right here (in West Virginia), they are building new houses … so that 321 Syrian Muslims can move down into this neighborhood in two months. … (A funeral home) is to be torn down in two months, and a mosque is going to built there.', source='Posts on the internet', date='2019-03-05', veracity=0, image='', url='', explanation=''), Noticia(title="There's no court session between now and the end of this election.", source='Philadelphia', date='2020-09-20', veracity=0, image='', url='', explanation=''), Noticia(title='The proposal by President Joe Biden would put the U.S. "No. 2 in the world" for the highest corporate tax rate.', source='Remarks on "fox news sunday"', date='2021-04-04', veracity=0, image='', url='', explanation=''), Noticia(title='In the Alabama Senate runoff, "the candidate I endorsed (Luther Strange) went up MANY points after endorsement!', source='A tweet', date='2017-09-30', veracity=0, image='', url='', explanation=''), Noticia(title='The government will "go out and buy my breast pump for my babies.', source='An interview on "the laura ingraham show"', date='2011-02-15', veracity=0, image='', url='', explanation=''), Noticia(title='Lee County, Florida, wasn\'t "even in the cone" of Hurricane Ian 72 hours before landfall.', source='An interview with cnn', date='2022-10-02', veracity=0, image='', url='', explanation=''), Noticia(title="Medicare has at least $80 billion worth of fraud a year. That's a full 20 percent of every dollar that's spent on Medicare goes to fraud.", source="Fox news channel's on the record with greta van susteren", date='2009-08-24', veracity=0, image='', url='', explanation=''), Noticia(title='Says the United Nations plans to "implant everyone with a biometric ID.', source='A story', date='2020-02-20', veracity=0, image='', url='', explanation=''), Noticia(title='Israel is banning Christianity.', source='A facebook video', date='2023-04-20', veracity=0, image='', url='', explanation=''), Noticia(title='In 2002, "Iran was more or less an American ally.', source='A broadcast of msnbc\'s "andrea mitchell reports"', date='2014-01-28', veracity=0, image='', url='', explanation=''), Noticia(title='The deficit was on track to top $1 trillion the year I took office.', source='A televised address', date='2011-07-25', veracity=0, image='', url='', explanation=''), Noticia(title='Says middle-class New York State residents will have the "lowest tax rate in 70 years.', source='A press conference and several other recent public appearances', date='2016-06-22', veracity=0, image='', url='', explanation='')]

# %%
df_stratified = prepare_date_for_model(df_stratified)
df_stratified = prepare_text_classic(df_stratified, ['statement','speaker_description','justification'])
df_stratified = prepare_context_generic(df_stratified)
df_stratified = add_count_proportions(df_stratified)
df_stratified = process_subject(df_stratified)
df_stratified = remove_unused_columns(df_stratified)

df_stratified.head(20)
# Out:
#                                                  subject  year  month  day  \
# 20368  economy energy infrastructure transportation u...  2010      6   18
# 8157                      elections facebook_fact_checks  2022     11    9
# 18997                                               guns  2015     10   13
# 10984             immigration housing race_and_ethnicity  2019      3    5
# 13676                                      supreme_court  2020      9   20
# 13196                                 corporations taxes  2021      4    4
# 10770                           polls_and_public_opinion  2017      9   30
# 10741                            health_care women taxes  2011      2   15
# 14969                                        environment  2022     10    2
# 17105                               health_care medicare  2009      8   24
# 17596      fake_news privacy_issues facebook_fact_checks  2020      2   20
# 21953               israel religion facebook_fact_checks  2023      4   20
# 10366                          foreign_policy punditfact  2014      1   28
# 18617                             deficit federal_budget  2011      7   25
# 6478                                               taxes  2016      6   22
#
#        dayofweek                                    clean_statement  \
# 20368          4  addition percent sale tax would cost typical h...
# 8157           2  michigan attorney general race stolen middle n...
# 18997          1               sen sander vote five time brady bill
# 10984          1  right west virginia building new house syrian ...
# 13676          6                   there court session end election
# 13196          6  proposal president joe biden would put u world...
# 10770          5  alabama senate runoff candidate endorsed luthe...
# 10741          1                 government go buy breast pump baby
# 14969          6  lee county florida wasnt even cone hurricane i...
# 17105          0  medicare least billion worth fraud year thats ...
# 17596          3  say united nation plan implant everyone biomet...
# 21953          3                        israel banning christianity
# 10366          1                            iran less american ally
# 18617          0        deficit track top trillion year took office
# 6478           2  say middleclass new york state resident lowest...
#
#        statement_len_chars  statement_len_words  \
# 20368                   94                   12
# 8157                    63                    9
# 18997                   36                    7
# 10984                  127                   20
# 13676                   32                    5
# 13196                   73                   12
# 10770                   83                   11
# 10741                   34                    6
# 14969                   62                   10
# 17105                  101                   16
# 17596                   52                    8
# 21953                   27                    3
# 10366                   23                    4
# 18617                   43                    7
# 6478                    60                   10
#
#                                clean_speaker_description  \
# 20368  hillsborough area rapid transit hart agency op...
# 8157   poster instagram people share photo graphic so...
# 18997  hillary clinton democratic nominee president s...
# 10984              poster facebook social medium network
# 13676  joe biden president united state democrat bide...
# 13196  roy blunt junior u senator missouri formerly u...
# 10770  donald trump former president united state ele...
# 10741  michele bachmann first elected u congress repr...
# 14969  ron desantis announced may running president r...
# 17105     tom coburn former u senator oklahoma physician
# 17596                              blog posting internet
# 21953              poster facebook social medium network
# 10366               andrea mitchell journalist nbc msnbc
# 18617  barack obama former president united state oba...
# 6478   andrew cuomo democrat elected first term gover...
#
#        speaker_description_len_chars  ...  ctx_social_media ctx_verbal_event  \
# 20368                             83  ...             False            False
# 8157                              64  ...              True            False
# 18997                            340  ...             False             True
# 10984                             37  ...              True            False
# 13676                            389  ...             False            False
# 13196                            122  ...             False             True
# 10770                            232  ...              True            False
# 10741                            302  ...             False             True
# 14969                            338  ...             False             True
# 17105                             46  ...             False            False
# 17596                             21  ...             False            False
# 21953                             37  ...              True            False
# 10366                             36  ...             False            False
# 18617                            356  ...             False            False
# 6478                              58  ...             False             True
#
#        ctx_location  total_counts  true_prop  mostly_true_prop  \
# 20368         False             1   0.000000          1.000000
# 8157          False           617   0.004862          0.004862
# 18997         False           301   0.239203          0.252492
# 10984         False          2407   0.009971          0.020773
# 13676         False           268   0.093284          0.238806
# 13196         False            18   0.277778          0.111111
# 10770         False           974   0.036961          0.087269
# 10741         False            62   0.080645          0.064516
# 14969         False            50   0.040000          0.200000
# 17105         False            10   0.000000          0.200000
# 17596         False           732   0.010929          0.024590
# 21953         False          2407   0.009971          0.020773
# 10366         False             4   0.000000          0.500000
# 18617         False           603   0.205638          0.273632
# 6478          False            38   0.394737          0.131579
#
#        half_true_prop  mostly_false_prop  false_prop  pants_on_fire_prop
# 20368        0.000000           0.000000    0.000000            0.000000
# 8157         0.024311           0.082658    0.656402            0.226904
# 18997        0.232558           0.142857    0.102990            0.029900
# 10984        0.044869           0.101786    0.585791            0.236809
# 13676        0.242537           0.194030    0.205224            0.026119
# 13196        0.222222           0.166667    0.166667            0.055556
# 10770        0.123203           0.199179    0.369610            0.183778
# 10741        0.096774           0.129032    0.370968            0.258065
# 14969        0.180000           0.260000    0.280000            0.040000
# 17105        0.300000           0.200000    0.300000            0.000000
# 17596        0.032787           0.072404    0.318306            0.540984
# 21953        0.044869           0.101786    0.585791            0.236809
# 10366        0.250000           0.000000    0.250000            0.000000
# 18617        0.270315           0.117745    0.117745            0.014925
# 6478         0.210526           0.184211    0.078947            0.000000
#
# [15 rows x 26 columns]

# %%
y_pred = models['XGBoost'].predict(df_stratified)

# Mapeo de índices a valores
mapping = np.array([0, 20, 40, 50, 75, 100])

# Aplicar el mapeo y luego multiplicar por 0.15
raw = mapping[y_pred] - 15
mapped = np.clip(raw, 0, None)

print(mapped)
# Out:
# [60  5 85  5 85 35  5  5 25 60  0  5  5 60 85]

# %%
import pandas as pd

# Función para humanizar dinámicamente nombres de features
def humanize_feature(name):
    # Mapas de prefijos a plantillas
    prefix_map = {
        'nums__': lambda m: (
            f"proportion of {m[:-5].replace('_', ' ')} statements"
            if m.endswith('_prop') else
            (f"length of {m[:-10].replace('_', ' ')} in characters"
             if m == m.endswith('_len_chars') else
             f"length of {m[:-10].replace('_', ' ')} in words"
             if m == m.endswith('_len_words') else
             "total number of words")
        ),
        'justf__tfidf_word__': lambda m: f'the word token "{m}" in the justification',
        'justf__tfidf_char__': lambda m: f'the character token "{m}" in the justification',
        'spkdesc__tfidf_word__': lambda m: f'the word token "{m}" in the speaker description',
        'spkdesc__tfidf_char__': lambda m: f'the character token "{m}" in the speaker description',
        'stmt__tfidf_word__': lambda m: f'the word token "{m}" in the statement',
        'stmt__tfidf_char__': lambda m: f'the character token "{m}" in the statement',
        'subj__tfidf_char__': lambda m: f'the character token "{m}" in the subject',
        'subj__tfidf_word__': lambda m: f'the word token "{m}" in the subject',
        'cats__': lambda m: f"category '{m.replace('_', ' ')}'"
    }
    for prefix, template in prefix_map.items():
        if name.startswith(prefix):
            metric = name[len(prefix):]
            return template(metric)
    # Fallback genérico
    return name.replace('__', ' ').replace('_', ' ')

# %%
import numpy as np
import shap
import pandas as pd

X_train, X_val, X_test, y_train, y_val, y_test = data_split()

vectorizer = models['XGBoost'].named_steps['pre']
clf        = models['XGBoost'].named_steps['clf']

# Transform and cache X_train as a 2D array for the explainer
X_train_vec = vectorizer.transform(X_train)
X_train_arr = X_train_vec.toarray().astype(float)

explainer = shap.TreeExplainer(
    clf,
    data=X_train_arr,
    feature_perturbation='interventional'
)

labels = ['Pants on fire', 'False', 'Barely-true', 'Half-true', 'Mostly-true', 'True']
all_frases = []
c = 0

for idx, row in df_stratified.iterrows():
    # 2.1) Extract the raw document/text for this row
    #     (adjust 'statement' to whatever your text-column is called)
    doc = row['clean_statement']
    
    X_test_vec = vectorizer.transform(df_stratified.loc[[idx]])
    X_test_arr = X_test_vec.toarray().astype(float)
    
    pred_class = clf.predict(X_test_arr)[0]

    # 2.4) Compute SHAP values for that one sample
    sv = explainer.shap_values(X_test_arr, check_additivity=False)
    # sv has shape (1, n_features, n_classes)
    vals = sv[0, :, pred_class]
    
    # 2.5) Build (feature_name, shap_value) pairs and sort by absolute impact
    feature_names = vectorizer.get_feature_names_out()
    shap_contribs = list(zip(feature_names, vals))
    shap_contribs.sort(key=lambda x: abs(x[1]), reverse=True)
    
    # 2.6) Humanize the top-5 and store the English sentences
    frases = []
    for feat, val in shap_contribs[:5]:
        desc  = humanize_feature(feat)
        signo = "positively" if val>0 else "negatively"
        frases.append(
            f'The presence of "{desc}" influence {signo} the probability of the {labels[y_pred[c]]} class'
        )

    c+=1
    
    all_frases.append(frases)

# %%
all_frases
# Out:
# [['The presence of "proportion of mostly false statements" influence negatively the probability of the Mostly-true class',
#   'The presence of "the character token "ill" in the speaker description" influence positively the probability of the Mostly-true class',
#   'The presence of "the character token "tax" in the statement" influence positively the probability of the Mostly-true class',
#   'The presence of "the character token "ica" in the justification" influence negatively the probability of the Mostly-true class',
#   'The presence of "the character token " sta" in the justification" influence negatively the probability of the Mostly-true class'],
#  ['The presence of "proportion of mostly false statements" influence positively the probability of the False class',
#   'The presence of "the character token "ica" in the justification" influence negatively the probability of the False class',
#   'The presence of "the character token " sta" in the justification" influence negatively the probability of the False class',
#   'The presence of "the character token "ess" in the justification" influence negatively the probability of the False class',
#   'The presence of "the character token "nt " in the justification" influence positively the probability of the False class'],
#  ['The presence of "proportion of mostly false statements" influence positively the probability of the True class',
#   'The presence of "the character token "erall" in the justification" influence negatively the probability of the True class',
#   'The presence of "the character token "ill" in the speaker description" influence positively the probability of the True class',
#   'The presence of "the character token " de" in the speaker description" influence negatively the probability of the True class',
#   'The presence of "the character token "ban" in the speaker description" influence positively the probability of the True class'],
#  ['The presence of "proportion of mostly false statements" influence positively the probability of the False class',
#   'The presence of "the word token "fact" in the justification" influence negatively the probability of the False class',
#   'The presence of "the character token "ct " in the justification" influence positively the probability of the False class',
#   'The presence of "the character token "ica" in the justification" influence negatively the probability of the False class',
#   'The presence of "the character token "nt " in the justification" influence positively the probability of the False class'],
#  ['The presence of "proportion of mostly false statements" influence positively the probability of the True class',
#   'The presence of "the word token "poll" in the justification" influence negatively the probability of the True class',
#   'The presence of "the character token " de" in the speaker description" influence negatively the probability of the True class',
#   'The presence of "the character token "ver" in the speaker description" influence negatively the probability of the True class',
#   'The presence of "the character token "ion" in the statement" influence positively the probability of the True class'],
#  ['The presence of "proportion of mostly false statements" influence positively the probability of the Half-true class',
#   'The presence of "the character token "nt " in the justification" influence negatively the probability of the Half-true class',
#   'The presence of "the character token "highe" in the statement" influence negatively the probability of the Half-true class',
#   'The presence of "the character token "onal " in the justification" influence positively the probability of the Half-true class',
#   'The presence of "the character token "iden" in the justification" influence positively the probability of the Half-true class'],
#  ['The presence of "proportion of mostly false statements" influence positively the probability of the False class',
#   'The presence of "the word token "poll" in the justification" influence negatively the probability of the False class',
#   'The presence of "the character token "nt " in the justification" influence negatively the probability of the False class',
#   'The presence of "the character token "ate " in the statement" influence negatively the probability of the False class',
#   'The presence of "the character token "ate" in the speaker description" influence negatively the probability of the False class'],
#  ['The presence of "proportion of mostly false statements" influence positively the probability of the False class',
#   'The presence of "the word token "statement" in the justification" influence negatively the probability of the False class',
#   'The presence of "the character token "nt " in the justification" influence negatively the probability of the False class',
#   'The presence of "the character token "ica" in the justification" influence positively the probability of the False class',
#   'The presence of "the character token " sta" in the justification" influence negatively the probability of the False class'],
#  ['The presence of "proportion of mostly false statements" influence positively the probability of the Barely-true class',
#   'The presence of "the character token "res" in the speaker description" influence negatively the probability of the Barely-true class',
#   'The presence of "the character token "ver" in the speaker description" influence negatively the probability of the Barely-true class',
#   'The presence of "the character token " de" in the speaker description" influence negatively the probability of the Barely-true class',
#   'The presence of "the character token "ica" in the justification" influence positively the probability of the Barely-true class'],
#  ['The presence of "proportion of mostly false statements" influence positively the probability of the Mostly-true class',
#   'The presence of "the character token "med" in the justification" influence positively the probability of the Mostly-true class',
#   'The presence of "the character token "ica" in the justification" influence positively the probability of the Mostly-true class',
#   'The presence of "the character token " sta" in the justification" influence negatively the probability of the Mostly-true class',
#   'The presence of "total number of words" influence positively the probability of the Mostly-true class'],
#  ['The presence of "proportion of mostly false statements" influence positively the probability of the Pants on fire class',
#   'The presence of "the character token " uni" in the statement" influence positively the probability of the Pants on fire class',
#   'The presence of "the character token "ct " in the justification" influence positively the probability of the Pants on fire class',
#   'The presence of "the character token "ica" in the justification" influence negatively the probability of the Pants on fire class',
#   'The presence of "the character token "ati" in the statement" influence positively the probability of the Pants on fire class'],
#  ['The presence of "proportion of mostly false statements" influence positively the probability of the False class',
#   'The presence of "the character token "ica" in the justification" influence negatively the probability of the False class',
#   'The presence of "the character token " pro" in the justification" influence positively the probability of the False class',
#   'The presence of "the character token "ll " in the justification" influence positively the probability of the False class',
#   'The presence of "the character token "ally " in the justification" influence negatively the probability of the False class'],
#  ['The presence of "proportion of mostly false statements" influence negatively the probability of the False class',
#   'The presence of "the character token "gn_" in the subject" influence positively the probability of the False class',
#   'The presence of "the character token "ica" in the justification" influence positively the probability of the False class',
#   'The presence of "the character token "ct " in the justification" influence positively the probability of the False class',
#   'The presence of "the character token "ll " in the justification" influence positively the probability of the False class'],
#  ['The presence of "proportion of mostly false statements" influence positively the probability of the Mostly-true class',
#   'The presence of "the word token "significant" in the justification" influence negatively the probability of the Mostly-true class',
#   'The presence of "the character token "ill" in the speaker description" influence positively the probability of the Mostly-true class',
#   'The presence of "the character token "ate " in the speaker description" influence positively the probability of the Mostly-true class',
#   'The presence of "the character token "ica" in the justification" influence positively the probability of the Mostly-true class'],
#  ['The presence of "proportion of mostly false statements" influence positively the probability of the True class',
#   'The presence of "the character token "ver" in the speaker description" influence negatively the probability of the True class',
#   'The presence of "the character token " low" in the statement" influence positively the probability of the True class',
#   'The presence of "the character token "ica" in the justification" influence negatively the probability of the True class',
#   'The presence of "the character token " pro" in the justification" influence positively the probability of the True class']]

# %%
urlList = [
'http://www.gohart.org/whytransit/rapid_transit_solutions.pdf',
'https://www.instagram.com/p/CkuwF1BuNWI/',
"https://www.politifact.com/factchecks/2020/mar/09/joe-biden/did-bernie-sanders-vote-against-brady-bill-five-ti/",
"https://www.facebook.com/jason.j.britt/videos/1332903936746386/",
"https://www.factcheck.org/2020/09/bidens-false-and-exaggerated-supreme-court-claims/",
"https://www.youtube.com/watch?v=9xp15zEcWUE&ab_channel=RoyBlunt",
"https://x.com/realDonaldTrump/status/914269704440737792",
"https://www.tampabay.com/archive/2011/02/18/michele-bachmann-says-the-government-will-buy-you-a-breast-pump-for-your-baby/",
"https://www.washingtonpost.com/politics/2022/10/03/ian-evacuation-lee-county-desantis-fema/",
"http://www.foxnews.com/story/0,2933,542384,00.html",
"https://www.m2sys.com/blog/biometric-resources/the-un-plans-to-implant-everyone-with-a-biometric-id-by-2030/",
"https://www.theguardian.com/world/2023/apr/13/christians-are-in-danger-under-israeli-government-says-holy-land-patriarch",
"https://www.breitbart.com/the-media/2014/01/28/nbc-andrea-mitchell-iran-an-american-ally-in-war-on-terror-until-bush-blew-it/",
"https://www.nytimes.com/2011/07/24/opinion/sunday/24sun4.html?_r=1",
"https://www.governor.ny.gov/news/video-rush-transcript-governor-hochul-guest-cnn-news-central"
]

imageList = [
'https://www.floridaforboomers.com/wp-content/uploads/2023/05/On-the-Water-in-Naples-Florida-1024x576.jpg',
'https://pbs.twimg.com/media/FhIKeSKXEAAQvNW?format=jpg&name=medium',
"https://static01.nyt.com/images/2020/02/25/us/politics/25breakout-sanders-guns/25breakout-sanders-guns-videoSixteenByNineJumbo1600.jpg",
"https://www.100daysinappalachia.com/wp-content/uploads/2019/03/0331_Screen-Shot-2019-03-18-at-8.13.48-AM-1024x538.png",
"https://ncnewsline.com/wp-content/uploads/2024/11/Riggs-Griffin-900.jpg",
"https://i.ytimg.com/vi/_5IsG7l7IXM/maxresdefault.jpg",
"https://static01.nyt.com/images/2017/12/14/us/politics/14dc-factcheck/merlin_127757144_06d0575b-61ae-4f75-b951-8388f11c5dac-articleLarge.jpg?quality=75&auto=webp&disable=upscale",
"https://cdnph.upi.com/sv/ph/og/upi/19971300229673/2011/1/406e4f78f16a30639665a2f710288a2e/v1.5/Bachmann-says-media-overplays-her-gaffes.jpg",
"https://www.tallahassee.com/gcdn/presto/2022/10/05/PTAL/90e56b62-4abc-46ce-9435-641256ec35aa-Hurricane_Cone_at_11.jpg?width=897&height=736&fit=crop&format=pjpg&auto=webp",
"https://www.gao.gov/assets/extracts/a5436ee7d20cf3ec8e741f872e346440/rId17_image3.png",
"https://www.un.org/sites/un2.un.org/files/world-leaders-adopt-pivotal-un-pact-for-the-future.jpg",
"https://images.csmonitor.com/csm/2023/04/0414%20OJLMCHRISTIANS%20crosses.jpg?alias=standard_900x600",
"https://media.breitbart.com/media/cdn/mediaserver/Breitbart/Big-Journalism/2012/MSNBC/Andrea%20Mitchell.jpg",
"https://i.ytimg.com/vi/K0UXnARjd3g/sddefault.jpg",
"https://static.politifact.com/CACHE/images/politifact/photos/HochulSuffolk050525/4780ba46f548ba4c7585329b3ae45d78.jpg"
]

# %%
df_noticias = pd.DataFrame([noticia.__dict__ for noticia in noticias])

df_noticias['veracity'] = mapped

df_noticias['explanation'] = all_frases

df_noticias['image'] = imageList

df_noticias['url'] = urlList
# y luego:
df_noticias.head(20)
# Out:
#                                                 title  \
# 0   The addition of a 1 percent sales tax would co...
# 1   The Michigan attorney general's race was "stol...
# 2   Sen. Sanders did vote five times against the B...
# 3   Right here (in West Virginia), they are buildi...
# 4   There's no court session between now and the e...
# 5   The proposal by President Joe Biden would put ...
# 6   In the Alabama Senate runoff, "the candidate I...
# 7   The government will "go out and buy my breast ...
# 8   Lee County, Florida, wasn't "even in the cone"...
# 9   Medicare has at least $80 billion worth of fra...
# 10  Says the United Nations plans to "implant ever...
# 11                    Israel is banning Christianity.
# 12  In 2002, "Iran was more or less an American ally.
# 13  The deficit was on track to top $1 trillion th...
# 14  Says middle-class New York State residents wil...
#
#                                                source        date  veracity  \
# 0                                          A brochure  2010-06-18        60
# 1                                   An instagram post  2022-11-09         5
# 2                         The first democratic debate  2015-10-13        85
# 3                               Posts on the internet  2019-03-05         5
# 4                                        Philadelphia  2020-09-20        85
# 5                        Remarks on "fox news sunday"  2021-04-04        35
# 6                                             A tweet  2017-09-30         5
# 7           An interview on "the laura ingraham show"  2011-02-15         5
# 8                               An interview with cnn  2022-10-02        25
# 9   Fox news channel's on the record with greta va...  2009-08-24        60
# 10                                            A story  2020-02-20         0
# 11                                   A facebook video  2023-04-20         5
# 12   A broadcast of msnbc's "andrea mitchell reports"  2014-01-28         5
# 13                                A televised address  2011-07-25        60
# 14  A press conference and several other recent pu...  2016-06-22        85
#
#                                                 image  \
# 0   https://www.floridaforboomers.com/wp-content/u...
# 1   https://pbs.twimg.com/media/FhIKeSKXEAAQvNW?fo...
# 2   https://static01.nyt.com/images/2020/02/25/us/...
# 3   https://www.100daysinappalachia.com/wp-content...
# 4   https://ncnewsline.com/wp-content/uploads/2024...
# 5   https://i.ytimg.com/vi/_5IsG7l7IXM/maxresdefau...
# 6   https://static01.nyt.com/images/2017/12/14/us/...
# 7   https://cdnph.upi.com/sv/ph/og/upi/19971300229...
# 8   https://www.tallahassee.com/gcdn/presto/2022/1...
# 9   https://www.gao.gov/assets/extracts/a5436ee7d2...
# 10  https://www.un.org/sites/un2.un.org/files/worl...
# 11  https://images.csmonitor.com/csm/2023/04/0414%...
# 12  https://media.breitbart.com/media/cdn/mediaser...
# 13   https://i.ytimg.com/vi/K0UXnARjd3g/sddefault.jpg
# 14  https://static.politifact.com/CACHE/images/pol...
#
#                                                   url  \
# 0   http://www.gohart.org/whytransit/rapid_transit...
# 1            https://www.instagram.com/p/CkuwF1BuNWI/
# 2   https://www.politifact.com/factchecks/2020/mar...
# 3   https://www.facebook.com/jason.j.britt/videos/...
# 4   https://www.factcheck.org/2020/09/bidens-false...
# 5   https://www.youtube.com/watch?v=9xp15zEcWUE&ab...
# 6   https://x.com/realDonaldTrump/status/914269704...
# 7   https://www.tampabay.com/archive/2011/02/18/mi...
# 8   https://www.washingtonpost.com/politics/2022/1...
# 9   http://www.foxnews.com/story/0,2933,542384,00....
# 10  https://www.m2sys.com/blog/biometric-resources...
# 11  https://www.theguardian.com/world/2023/apr/13/...
# 12  https://www.breitbart.com/the-media/2014/01/28...
# 13  https://www.nytimes.com/2011/07/24/opinion/sun...
# 14  https://www.governor.ny.gov/news/video-rush-tr...
#
#                                           explanation
# 0   [The presence of "proportion of mostly false s...
# 1   [The presence of "proportion of mostly false s...
# 2   [The presence of "proportion of mostly false s...
# 3   [The presence of "proportion of mostly false s...
# 4   [The presence of "proportion of mostly false s...
# 5   [The presence of "proportion of mostly false s...
# 6   [The presence of "proportion of mostly false s...
# 7   [The presence of "proportion of mostly false s...
# 8   [The presence of "proportion of mostly false s...
# 9   [The presence of "proportion of mostly false s...
# 10  [The presence of "proportion of mostly false s...
# 11  [The presence of "proportion of mostly false s...
# 12  [The presence of "proportion of mostly false s...
# 13  [The presence of "proportion of mostly false s...
# 14  [The presence of "proportion of mostly false s...

# %%
import json

json_str = df_noticias.to_json(
    orient='records',
    force_ascii=False,    
    date_format='iso'     
)

print(json_str)

with open('noticias.json', 'w', encoding='utf-8') as f:
    f.write(json_str)
# Out:
# [{"title":"The addition of a 1 percent sales tax would cost a typical household in Hillsborough County approximately $12 a month.","source":"A brochure","date":"2010-06-18","veracity":60,"image":"https:\/\/www.floridaforboomers.com\/wp-content\/uploads\/2023\/05\/On-the-Water-in-Naples-Florida-1024x576.jpg","url":"http:\/\/www.gohart.org\/whytransit\/rapid_transit_solutions.pdf","explanation":["The presence of \"proportion of mostly false statements\" influence negatively the probability of the Mostly-true class","The presence of \"the character token \"ill\" in the speaker description\" influence positively the probability of the Mostly-true class","The presence of \"the character token \"tax\" in the statement\" influence positively the probability of the Mostly-true class","The presence of \"the character token \"ica\" in the justification\" influence negatively the probability of the Mostly-true class","The presence of \"the character token \" sta\" in the justification\" influence negatively the probability of the Mostly-true class"]},{"title":"The Michigan attorney general's race was \"stolen in the middle of the night from Matt DePerno.","source":"An instagram post","date":"2022-11-09","veracity":5,"image":"https:\/\/pbs.twimg.com\/media\/FhIKeSKXEAAQvNW?format=jpg&name=medium","url":"https:\/\/www.instagram.com\/p\/CkuwF1BuNWI\/","explanation":["The presence of \"proportion of mostly false statements\" influence positively the probability of the False class","The presence of \"the character token \"ica\" in the justification\" influence negatively the probability of the False class","The presence of \"the character token \" sta\" in the justification\" influence negatively the probability of the False class","The presence of \"the character token \"ess\" in the justification\" influence negatively the probability of the False class","The presence of \"the character token \"nt \" in the justification\" influence positively the probability of the False class"]},{"title":"Sen. Sanders did vote five times against the Brady bill.","source":"The first democratic debate","date":"2015-10-13","veracity":85,"image":"https:\/\/static01.nyt.com\/images\/2020\/02\/25\/us\/politics\/25breakout-sanders-guns\/25breakout-sanders-guns-videoSixteenByNineJumbo1600.jpg","url":"https:\/\/www.politifact.com\/factchecks\/2020\/mar\/09\/joe-biden\/did-bernie-sanders-vote-against-brady-bill-five-ti\/","explanation":["The presence of \"proportion of mostly false statements\" influence positively the probability of the True class","The presence of \"the character token \"erall\" in the justification\" influence negatively the probability of the True class","The presence of \"the character token \"ill\" in the speaker description\" influence positively the probability of the True class","The presence of \"the character token \" de\" in the speaker description\" influence negatively the probability of the True class","The presence of \"the character token \"ban\" in the speaker description\" influence positively the probability of the True class"]},{"title":"Right here (in West Virginia), they are building new houses … so that 321 Syrian Muslims can move down into this neighborhood in two months. … (A funeral home) is to be torn down in two months, and a mosque is going to built there.","source":"Posts on the internet","date":"2019-03-05","veracity":5,"image":"https:\/\/www.100daysinappalachia.com\/wp-content\/uploads\/2019\/03\/0331_Screen-Shot-2019-03-18-at-8.13.48-AM-1024x538.png","url":"https:\/\/www.facebook.com\/jason.j.britt\/videos\/1332903936746386\/","explanation":["The presence of \"proportion of mostly false statements\" influence positively the probability of the False class","The presence of \"the word token \"fact\" in the justification\" influence negatively the probability of the False class","The presence of \"the character token \"ct \" in the justification\" influence positively the probability of the False class","The presence  ...
